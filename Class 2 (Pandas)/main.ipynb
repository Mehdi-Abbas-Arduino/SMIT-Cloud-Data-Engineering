# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# #### Importing data

# %%
df = pd.read_csv('nobel.csv',delimiter=',',header=2)

# %%
df
# Out:
#      1901  Literature                 The Nobel Prize in Literature 1901  \
# 0    1901    Medicine     The Nobel Prize in Physiology or Medicine 1901
# 1    1901       Peace                         The Nobel Peace Prize 1901
# 2    1901       Peace                         The Nobel Peace Prize 1901
# 3    1901     Physics                    The Nobel Prize in Physics 1901
# 4    1902   Chemistry                  The Nobel Prize in Chemistry 1902
# ..    ...         ...                                                ...
# 993  2023   Chemistry                  The Nobel Prize in Chemistry 2023
# 994  2023   Chemistry                  The Nobel Prize in Chemistry 2023
# 995  2023  Literature                 The Nobel Prize in Literature 2023
# 996  2023       Peace                         The Nobel Peace Prize 2023
# 997  2023   Economics  The Sveriges Riksbank Prize in Economic Scienc...
#
# ...

# %%
# Seeing Sample Data
df.head()
# Out:
#    1901 Literature              The Nobel Prize in Literature 1901  \
# 0  1901   Medicine  The Nobel Prize in Physiology or Medicine 1901
# 1  1901      Peace                      The Nobel Peace Prize 1901
# 2  1901      Peace                      The Nobel Peace Prize 1901
# 3  1901    Physics                 The Nobel Prize in Physics 1901
# 4  1902  Chemistry               The Nobel Prize in Chemistry 1902
#
#   "in special recognition of his poetic composition, which gives evidence of lofty idealism, artistic perfection and a rare combination of the qualities of both heart and intellect"  \
# 0  "for his work on serum therapy, especially its...
# 1                                                NaN
# 2                                                NaN
# 3  "in recognition of the extraordinary services ...
# 4  "in recognition of the extraordinary services ...
#
#    1/1  569  Individual         Sully Prudhomme  1839-03-16  \
# ...

# %%
df = pd.read_excel(r"C:\Users\mehdi\Desktop\SMIT - Cloud Data Engineering\Class 2 (Pandas)\titanic.xlsx")
# Sheet name required if you have multiple sheets cause it will only read 1 sheet
# Out:
# c:\Users\mehdi\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
df
# Out:
#       pclass  survived                                  name     sex      age  \
# 0          1         1                        Haghish, E. F.    male  30.0000
# 1          1         1         Allen, Miss. Elisabeth Walton  female  29.0000
# 2          1         1        Allison, Master. Hudson Trevor    male   0.9167
# 3          1         0          Allison, Miss. Helen Loraine  female   2.0000
# 4          1         0  Allison, Mr. Hudson Joshua Creighton    male  30.0000
# ...      ...       ...                                   ...     ...      ...
# 1305       3         0                  Zabour, Miss. Hileni  female  14.5000
# 1306       3         0                 Zabour, Miss. Thamine  female      NaN
# 1307       3         0             Zakarian, Mr. Mapriededer    male  26.5000
# 1308       3         0                   Zakarian, Mr. Ortin    male  27.0000
# 1309       3         0                    Zimmerman, Mr. Leo    male  29.0000
#
# ...

# %%
df.head()
# Out:
#    pclass  survived                                  name     sex      age  \
# 0       1         1                        Haghish, E. F.    male  30.0000
# 1       1         1         Allen, Miss. Elisabeth Walton  female  29.0000
# 2       1         1        Allison, Master. Hudson Trevor    male   0.9167
# 3       1         0          Allison, Miss. Helen Loraine  female   2.0000
# 4       1         0  Allison, Mr. Hudson Joshua Creighton    male  30.0000
#
#    sibsp  parch  ticket      fare       cabin embarked boat   body  \
# 0      0      0   24058   26.5500  A1 Special        S    1    NaN
# 1      0      0   24160  211.3375          B5        S    2    NaN
# 2      1      2  113781  151.5500     C22 C26        S   11    NaN
# 3      1      2  113781  151.5500     C22 C26        S  NaN    NaN
# 4      1      2  113781  151.5500     C22 C26        S  NaN  135.0
#
#                          home.dest
# 0                  Odense, Denmark
# 1                     St Louis, MO
# ...

# %%
df = pd.read_csv(r"C:\Users\mehdi\Desktop\SMIT - Cloud Data Engineering\Class 2 (Pandas)\pIBpry.tsv",delimiter='\t')

# %%
df.tail()
# Out:
#      To Do Unnamed: 1 1/3 completed
# 44   FALSE        NaN             NaN
# 45   FALSE        NaN             NaN
# 46   FALSE        NaN             NaN
# 47   FALSE        NaN             NaN
# 48   FALSE        NaN             NaN

# %%
df.shape
# Out:
# (49, 3)

# %%
df.shape[0] # Rows
# Out:
# 49

# %%
df.shape[1] # Columns
# Out:
# 3

# %%
df.columns
# Out:
# Index(['  To Do', 'Unnamed: 1', '1/3 completed  '], dtype='object')

# %%
for i in df.columns:
    print(i)
# Out:
#   To Do
# Unnamed: 1
# 1/3 completed

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Checking datatype of each column 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0     To Do          48 non-null     object
#  1   Unnamed: 1       4 non-null      object
#  2   1/3 completed    4 non-null      object
# dtypes: object(3)
# memory usage: 1.3+ KB

# %%
# stats description
df.describe()
# Out:
#          To Do Unnamed: 1 1/3 completed
# count       48          4               4
# unique       3          4               4
# top      FALSE       Date            Task
# freq        46          1               1

# %%
df.describe(include='all')
# Out:
#          To Do Unnamed: 1 1/3 completed
# count       48          4               4
# unique       3          4               4
# top      FALSE       Date            Task
# freq        46          1               1

# %%
df.describe(include='object')
# Out:
#          To Do Unnamed: 1 1/3 completed
# count       48          4               4
# unique       3          4               4
# top      FALSE       Date            Task
# freq        46          1               1
